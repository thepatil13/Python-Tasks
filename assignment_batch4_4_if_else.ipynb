# %% [markdown]
# ### 1. Write a program to check if a number is positive.

# %%
a=9
if a>=0:
    print("Number is Positive")
else:
    print("Number is Negative")
# Out:
# Number is Positive

# %% [markdown]
# ### 2. Check if a number is even or odd.

# %%
a=9
if a%2==0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %% [markdown]
# ### 3. Check if a person is eligible to vote (age >= 18).

# %%
a=23
if a>=18:
    print("Person is eligible for vote")
else:
    print("Not eligilble")
# Out:
# Person is eligible for vote

# %% [markdown]
# ### 4. Check if a number is greater than 100.

# %%
a=101
if a>100:
    print("Number is greater than 100")
else:
    print("Number is smaller than 100")
# Out:
# Number is greater than 100

# %% [markdown]
# ### 5. Print “Adult” if age > 18 else print “Child”.

# %%
a=17
if a>18:
    print("Adult")
else:
    print("Child")
# Out:
# Child

# %% [markdown]
# ### 6. Check if two numbers are equal.

# %%
a=10
b=20
if a==b:
    print("numbers are equal")
else:
    print("numbers are not equal")
# Out:
# numbers are not equal

# %% [markdown]
# ### 7. Check if a number is divisible by 5.

# %%
num=50
if num%5==0:
    print("Number is divisible by 5")
else:
    print("Number is not divisible by 5")
# Out:
# Number is divisible by 5

# %% [markdown]
# ### 8. Check if a string is “hello”.

# %%
a="Hello"
if a=="Hello":
    print(f"'{a}'")
else:
    print("Null")
# Out:
# 'Hello'

# %% [markdown]
# ### 9. Print the larger of two numbers.

# %%
num1=1000
num2=999
if num1>num2:
    print(num1)
else:
    print(num2)
# Out:
# 1000

# %% [markdown]
# ### 10. Check if a number is negative

# %%
num=-1
if num<0:
    print("Negative Number")
else:
    print("Positive Number")
# Out:
# Negative Number

# %% [markdown]
# ### 11. Check if a number is positive, negative, or zero.

# %%
num=0
if num<0:
    print("Negative Number")
elif num>0:
    print("Positive Number")
else:
    print("Number is 0")
# Out:
# Number is 0

# %% [markdown]
# ### 12. Check if a year is a leap year.

# %%
year=2025
if year%4==0:
    print("Leap Year")
else:
    print("Not a leap year")
# Out:
# Not a leap year

# %% [markdown]
# ### 13. Check if a character is a vowel or consonant.

# %%
ch="a"
if ch in "a,e,i,o,u,A,E,I,O,U":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Vowel

# %% [markdown]
# ### 14. Print the greatest of three numbers.

# %%
num1=13
num2=23
num3=9
if num1>num2 and num1>num3:
    print(num1)
elif num2>num3 and num2>num1:
    print(num2)
else:
    print(num3)
# Out:
# 23

# %% [markdown]
# ### 15. Check if a password length is strong (>= 8).

# %%
a="abscasas"
if len(a)>=8:
    print("Strong Password")
else:
    print("Poor Password")
# Out:
# Strong Password

# %% [markdown]
# ### 16. Check if a number lies between 10 and 50.

# %%
num=23
if num in range(10,51):
    print(num)
else:
    print("NUll")
# Out:
# 23

# %% [markdown]
# ### 17. Print the grade of a student (A, B, C, D, F) based on marks.

# %%
marks=40
if marks>90:
    print("A Grade")
elif 70<marks<=90:
    print("B Grade")
elif 60<marks<=70:
    print("C Grade")
elif 40 <marks<=60:
    print("D Grade")
elif marks<=40:
    print("F FAIL")
# Out:
# F FAIL

# %% [markdown]
# ### 18. Check if a number is divisible by both 2 and 3.

# %%
a=12
if a%2==0 and a%3==0:
    print("Number is divisible by both 2 and 3")
else:
    print("Number is not divisible by both 2 and 3")
# Out:
# Number is divisible by both 2 and 3

# %% [markdown]
# ### 19. Check if a person’s age falls into categories: child, teen, adult, senior.

# %%
age=40
if age>60:
    print("Senior")
elif 20<age<=60:
    print("Adult")
elif 13<marks<=19:
    print("Teen")
elif 1<marks<=12:
    print("Child")
# Out:
# Adult

# %% [markdown]
# ### 20. Check if a character is uppercase or lowercase.

# %%
ch="SUMEDH"
if ch.isupper():
    print("UPPERCASE")
else:
    print("lowercase")
# Out:
# UPPERCASE

# %% [markdown]
# ### 21. Check if a number is a multiple of 10.

# %%
num=22
if num%10==0:
    print("Multiple of 10")
else:
    print("Not a multiple of 10")
# Out:
# Not a multiple of 10

# %% [markdown]
# ### 22. Compare two numbers and print “greater”, “smaller”, or “equal”.

# %%
num1=23
num2=13
if num1>num2:
    print("greater")
elif num1<num2:
    print("smaller")
else:
    print("equal")
# Out:
# greater

# %% [markdown]
# ### 23. Check if a triangle is equilateral, isosceles, or scalene.

# %%
side_a=9
side_b=5
side_c=9
if side_a==side_b and side_b==side_c:
    print("Equilateral Triangle")
elif side_a==side_b or side_b==side_c or side_c==side_a:
    print("Isosceles Triangle")
else:
    print("Scalene Triangle")
# Out:
# Isosceles Triangle

# %% [markdown]
# ### 24. Check if a string contains the word “python”.

# %%
str="I am learning python "
if "python" in str:
    print("Present in string")
else:
    print("Not Present in string")
# Out:
# Present in string

# %% [markdown]
# ### 25. Check if a list has more than 5 elements.

# %%
lst=[1,2,3,4,5,6,7,8,9]
if len(lst)>5:
    print("List has more than 5 items")
else:
    print("List has less than 5 items")
# Out:
# List has more than 5 items

# %% [markdown]
# ### 26. Check if temperature is cold (<15), warm (15–30), or hot (>30).

# %%
temp=30
if temp>30:
    print("Hot")
elif 15<temp<=30:
    print("Warm")
elif temp<15:
    print("Cold")
# Out:
# Warm

# %% [markdown]
# ### 27. Check if a student passed (marks >= 40) else fail.

# %%
marks=35
if marks>=40:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %% [markdown]
# ### 28. Check if a number ends with digit 7.

# %%
num=int(input("Enetr any number-"))
if num%10==7:
    print("Number ends with 7")
else:
    print("Number not ends with 7")
# Out:
# Number ends with 7

# %% [markdown]
# ### 29. Check if the first character of a string is a vowel.

# %%
a="orange"
vowels=['a,e,i,o,u,A,E,I,O,U']
if a[0] in vowels:
    print("First character of string is vowel")
else:
    print("First character of string is not a vowel")
# Out:
# First character of string is not a vowel

# %% [markdown]
# ### 30. Check if a number is within 1 to 100, else print “out of range

# %%
a=int(input("Enter any number"))
if a in range(1,101):
    print(f"The number{a} lies between 1 to 100")
else:
    print(f"{a} out of range")
# Out:
# The number99 lies between 1 to 100

# %% [markdown]
# ### 31. Check if a number is prime using if-else (simple logic allowed).

# %%
nu=int(input("Enter a number -"))
count=0
for i in range(2,nu+1):
    if nu%i==0:
        count+=1
        break
if count>1:
    print("Number is not prime")
else:
    print("Number is prime")
# Out:
# Number is prime

# %% [markdown]
# ### 32. Check if the last digit of a number is even or odd.

# %%
num=int(input("Enter any number"))
num1=num%10
if num1%2==0:
    print(f"{num1} is even number")
else:
    print(f"{num1} is odd number")
# Out:
# 3 is odd number

# %% [markdown]
# ### 33. Check if the input is an integer or not (using string checks).

# %%
string=input("Enter any number")
if string.isdigit():
    print("Integer")
else:
    print("Not Integer")
# Out:
# Not Integer

# %% [markdown]
# ### 34. Check if three angles can form a valid triangle.

# %%
a=90
b=60
c=60
if a+b+c==180:
    print("Valid Triangle")
else:
    print("Not valid")
# Out:
# Not valid

# %% [markdown]
# ### 35. Check if two strings are anagrams (simple: check sorted equality).

# %%
str1="silent"
str2="listen"
if sorted(str1)==sorted(str2):
    print(f"{str1} and {str2} are anagrams")
else:
    print("Not anagrams")
# Out:
# silent and listen are anagrams

# %% [markdown]
# ### 36. Determine the type of triangle using sides: acute, right, obtuse.

# %%
t1=90
t2=90
t3=90
if t1<90 or t2<90 or t3<90:
    print("Its Acute Angle Triangle")
elif t1==90 or t2==90 or t3==90:
    print("Its Right Angle Triangle")
elif t1>90 or t2>90 or t3>90:
    print("Its Obtuse Angle Triangle")
# Out:
# Its Right Angle Triangle

# %% [markdown]
# ### 37. Check if a string is palindrome (case insensitive).

# %%
string1=input("Enter a character- ")
if string1==string1[::-1]:
    print("Character is palindrome")
else:
    print("Character is not palindrome")
# Out:
# Character is palindrome

# %% [markdown]
# ### 38. Check if the first and last characters of a string are same.

# %%
string=input("Enter a character")
if string[0]==string[-1]:
    print("First and last characters of string are same")
# Out:
# First and last characters of string are same

# %% [markdown]
# ### 39. Check if the sum of digits of a number is divisible by 3.

# %%
a=99
sum=0
for i in str(a):
    sum+=int(i)
if sum%3==0:
        print("Divisible by 3")
else:
        print("Not Divisible by 3")
# Out:
# Divisible by 3

# %% [markdown]
# ### 40. Check if a number is Armstrong (3-digit).

# %%
a=153
sum=0
for i in str(a):
    sum+=int(i)**3
if a==sum:
        print("Number is Armstrong Number")
else:
        print("Number is not a Armstrong Number")
# Out:
# Number is Armstrong Number

# %% [markdown]
# ### 41. Check if a number has exactly 3 digits.

# %%
a=123
if len(str(a))==3:
    print("Number has 3 digits") 
else:
    print("Number does not have 3 digits")
# Out:
# Number has 3 digits

# %% [markdown]
# ### 42. Check if a number is perfect (sum of factors equals number).

# %%
nu=28
sum=0
for i in range(1,nu):
    if nu%i==0:
        sum+=i
print(sum)
if sum==nu:
    print("Sum of factor is equals to number")
else:
    print("Sum of factor is not equals to number")
# Out:
# 28
# Sum of factor is equals to number

# %% [markdown]
# ### 43. Compare lengths of two strings and print which is longer.

# %%
str1=("abcdef")
str2=("abc")
if len(str1)>len(str2):
    print(f"{str1} is Longer")
else:
    print(f"{str2} is Longer")
# Out:
# abcdef is Longer

# %% [markdown]
# ### 44. Check if a list contains duplicates.

# %%
ls=[1,2,4,12,1,4,1,42]
seen=set()
duplicate=False
for i in ls:
    if i in seen:
        duplicate=True
        break
    seen.add(i)
if duplicate:
    print("List contains duplicate")
else:
    print("List don't have any duplicates")
# Out:
# List contains duplicate

# %% [markdown]
# ### 45. Check if a number is both prime AND even (only possible is 2).

# %%
nu=2
count=0
for i in range(1,nu):
    if nu%i==0:
        count+=1
if count==1 and nu%2==0:
    print("Number is prime and even")
else:
    print("Number is not prime and even")
# Out:
# Number is prime and even

# %% [markdown]
# ### 46. Print “YES” if any of the two numbers is zero else print “NO”.

# %%
n1=int(input("Enter any number"))
n2=int(input("Enter any number"))
if n1==0 or n2==0:
    print("one of two numbers is 0")
else:
    print("no one of them number is 0")
# Out:
# one of two numbers is 0

# %% [markdown]
# ### 47. Check if two numbers have the same last digit.

# %%
n1=int(input("Enter any number"))
n2=int(input("Enter any number"))
if n1%10==n2%10:
    print("Two numbers have the same last digit")
# Out:
# Two numbers have the same last digit

# %% [markdown]
# ### 48. Check if a password contains both letters and digits.

# %%
password=input("Enter Password-")
if password.isalpha():
    print("Password contains letters")
elif password.isdigit():
    print("Password  contains  digits")
elif password.isalnum():
      print("Password contains both letters and digits")
# Out:
# Password contains both letters and digits

# %% [markdown]
# ### 49. Check if a number is “lucky”: sum of first two digits equals last two digits.

# %%
a=(input("Enter number more than 4 digits-"))
if int(a[0])+int(a[1])==int(a[-2])+int(a[-1]):
    print("Its Lucky number")
else:
    print("Not lucky")
# Out:
# Its Lucky number

# %% [markdown]
# ### 50. Check if the absolute difference between two numbers is less than 10

# %%
num1=int(input("Enter any number-"))
num2=int(input("Enter any number-"))
if abs(num1-num2):
    print(f"Difference between {num1} and {num2} is less than 10")
else:
    print(f"Difference between {num1} and {num2} is more than 10")
# Out:
# Difference between 20 and 40 is less than 10

# %% [markdown]
# ### 51. Write a program to check if a variable is an integer using isinstance().

# %%
var=int(input("Enter any number"))
if isinstance(var,int):
    print("Number is integer")
else:
    print("Number is not integer")
# Out:
# Number is integer

# %% [markdown]
# ### 52. Check if a given input is a string using isinstance().

# %%
a=input("enter anything")
if isinstance(a,str):
    print("Its string")
else:
    print("Not a string")
# Out:
# Its string

# %% [markdown]
# ### 53. Check if a variable is a float and print “Float value found”.

# %%
a=eval(input("Enter any Number"))
if isinstance(a,float):
    print("Number is Float")
else:
    print("Number is not Float")
# Out:
# Number is Float

# %% [markdown]
# ### 54. Check if a variable is a list; if yes, print its length.

# %%
a=[1,2,3,4,5]
if isinstance(a,list):
    print(f"{len(a)}")
# Out:
# 5

# %% [markdown]
# ### 55. Write a program to check if a variable is a tuple; if yes, print the first element.

# %%
a=(1,2,3,4,5,6,7,8,9)
if isinstance(a,tuple):
    print("Variable is tuple")
    print(a[0])
else:
    print("Variable is not tuple")
# Out:
# Variable is tuple
# 1

# %% [markdown]
# ### 56. Check if a variable is a dictionary; if yes, print all keys.

# %%
a={"name":"sumedh","city":"kpolhapur","age":24}
if isinstance(a,dict):
    print(f"{a.keys()}")
# Out:
# dict_keys(['name', 'city', 'age'])

# %% [markdown]
# ### 57. Check if a variable is a set; if yes, print the number of elements.

# %%
a={1,2,3,4,5}
if isinstance(a,set):
    print(f"{len(a)}")
# Out:
# 5

# %% [markdown]
# ### 58. Check if a variable is a boolean and print “True/False detected”.

# %%
a=True
if isinstance(a,bool):
    print(f"{a} detected")
# Out:
# True detected

# %% [markdown]
# ### 59. Write a program to check if a variable is either int OR float (number check).

# %%
a=23
if isinstance(a,float):
    print("Float")
else:
    print("Int")
# Out:
# Int

# %% [markdown]
# ### 60. Check if a variable is NOT a list (using not isinstance()), and print: “Not a list”.

# %%
a=[1,2,3,4,5]
if not isinstance(a,list):
    print("Not a list")
else:
    print("Its list")
# Out:
# Its list
